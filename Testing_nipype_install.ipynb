# %%
import nipype

# Optional: Use the following lines to increase verbosity of output
# nipype.config.set('logging', 'workflow_level',  'CRITICAL')
# nipype.config.set('logging', 'interface_level', 'CRITICAL')
# nipype.logging.update_logging(nipype.config)

# Run the test: Increase verbosity parameter for more info
nipype.test(doctests=False)
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.6.8, pytest-4.3.1, py-1.8.0, pluggy-0.9.0
# rootdir: /home/jordan/anaconda3/lib/python3.6/site-packages/nipype, inifile: pytest.ini
# plugins: remotedata-0.3.1, openfiles-0.3.2, doctestplus-0.3.0, arraydiff-0.3
# 200723-09:35:15,758 nipype.interface WARNING:
# 	 VTK was not found
# 200723-09:35:15,759 nipype.interface WARNING:
# 	 tvtk wasn't found
# 200723-09:35:17,111 nipype.interface INFO:
# 	 We advise you to upgrade DIPY version. This upgrade will open access to more function
# 200723-09:35:17,116 nipype.interface INFO:
# 	 We advise you to upgrade DIPY version. This upgrade will open access to more function
# 200723-09:35:17,118 nipype.interface INFO:
# 	 We advise you to upgrade DIPY version. This upgrade will open access to more models
# collected 2297 items
#
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_CompCor.py E [  0%]
# EEEEEEEEEE                                                               [  0%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_ErrorMap.py E [  0%]
#                                                                          [  0%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_Overlap.py E [  0%]
#                                                                          [  0%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_TSNR.py E [  0%]
# EEEE                                                                     [  0%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_ACompCor.py E [  0%]
# E                                                                        [  0%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_ActivationCount.py E [  0%]
# E                                                                        [  0%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_AddCSVColumn.py E [  1%]
# E                                                                        [  1%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_AddCSVRow.py E [  1%]
# E                                                                        [  1%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_AddNoise.py E [  1%]
# E                                                                        [  1%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_ArtifactDetect.py E [  1%]
# E                                                                        [  1%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_CalculateMedian.py E [  1%]
# E                                                                        [  1%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_CalculateNormalizedMoments.py E [  1%]
# E                                                                        [  1%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_ComputeDVARS.py E [  1%]
# E                                                                        [  1%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_ComputeMeshWarp.py E [  1%]
# E                                                                        [  1%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_CreateNifti.py E [  1%]
# E                                                                        [  1%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_Distance.py E [  1%]
# E                                                                        [  1%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_FramewiseDisplacement.py E [  1%]
# E                                                                        [  1%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_FuzzyOverlap.py E [  1%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_Gunzip.py E [  2%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_ICC.py E [  2%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_Matlab2CSV.py E [  2%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_MergeCSVFiles.py E [  2%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_MergeROIs.py E [  2%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_MeshWarpMaths.py E [  2%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_ModifyAffine.py E [  2%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_NonSteadyStateDetector.py E [  2%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_NormalizeProbabilityMapSet.py E [  2%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_P2PDistance.py E [  2%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_PickAtlas.py E [  2%]
# E                                                                        [  2%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_Similarity.py E [  3%]
# E                                                                        [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_SimpleThreshold.py E [  3%]
# E                                                                        [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_SpecifyModel.py E [  3%]
# E                                                                        [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_SpecifySPMModel.py E [  3%]
# E                                                                        [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_SpecifySparseModel.py E [  3%]
# E                                                                        [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_SplitROIs.py E [  3%]
# E                                                                        [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_StimulusCorrelation.py E [  3%]
# E                                                                        [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_TCompCor.py E [  3%]
# E                                                                        [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_TVTKBaseInterface.py E [  3%]
#                                                                          [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_auto_WarpPoints.py E [  3%]
# E                                                                        [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_confounds.py E [  3%]
# EE                                                                       [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_icc_anova.py E [  3%]
#                                                                          [  3%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_mesh_ops.py s [  4%]
# sssE                                                                     [  4%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_metrics.py E [  4%]
#                                                                          [  4%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_misc.py E [  4%]
# E                                                                        [  4%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_modelgen.py E [  4%]
# EEE                                                                      [  4%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_moments.py E [  4%]
#                                                                          [  4%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_normalize_tpms.py E [  4%]
#                                                                          [  4%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_rapidart.py E [  4%]
# EEEEEE                                                                   [  4%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_splitmerge.py E [  4%]
#                                                                          [  4%]
# ../anaconda3/lib/python3.6/site-packages/nipype/algorithms/tests/test_stats.py E [  4%]
# EEE                                                                      [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/caching/tests/test_memory.py E [  5%]
#                                                                          [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_ABoverlap.py E [  5%]
# E                                                                        [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_AFNICommand.py E [  5%]
#                                                                          [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_AFNICommandBase.py E [  5%]
#                                                                          [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_AFNIPythonCommand.py E [  5%]
#                                                                          [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_AFNItoNIFTI.py E [  5%]
# E                                                                        [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_AlignEpiAnatPy.py E [  5%]
# E                                                                        [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Allineate.py E [  5%]
# E                                                                        [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_AutoTLRC.py E [  5%]
# E                                                                        [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_AutoTcorrelate.py E [  5%]
# E                                                                        [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Autobox.py E [  5%]
# E                                                                        [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Automask.py E [  5%]
# E                                                                        [  5%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Axialize.py E [  6%]
# E                                                                        [  6%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Bandpass.py E [  6%]
# E                                                                        [  6%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_BlurInMask.py E [  6%]
# E                                                                        [  6%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_BlurToFWHM.py E [  6%]
# E                                                                        [  6%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_BrickStat.py E [  6%]
# E                                                                        [  6%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Bucket.py E [  6%]
# E                                                                        [  6%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Calc.py E [  6%]
# E                                                                        [  6%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Cat.py E [  6%]
# E                                                                        [  6%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_CatMatvec.py E [  6%]
# E                                                                        [  6%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_CenterMass.py E [  6%]
# E                                                                        [  6%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_ClipLevel.py E [  6%]
# E                                                                        [  6%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_ConvertDset.py E [  6%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Copy.py E [  7%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Deconvolve.py E [  7%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_DegreeCentrality.py E [  7%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Despike.py E [  7%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Detrend.py E [  7%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Dot.py E [  7%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_ECM.py E [  7%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Edge3.py E [  7%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Eval.py E [  7%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_FWHMx.py E [  7%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Fim.py E [  7%]
# E                                                                        [  7%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Fourier.py E [  8%]
# E                                                                        [  8%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_GCOR.py E [  8%]
# E                                                                        [  8%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Hist.py E [  8%]
# E                                                                        [  8%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_LFCD.py E [  8%]
# E                                                                        [  8%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_LocalBistat.py E [  8%]
# E                                                                        [  8%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Localstat.py E [  8%]
# E                                                                        [  8%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_MaskTool.py E [  8%]
# E                                                                        [  8%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Maskave.py E [  8%]
# E                                                                        [  8%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Means.py E [  8%]
# E                                                                        [  8%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Merge.py E [  8%]
# E                                                                        [  8%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Notes.py E [  8%]
# E                                                                        [  8%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_NwarpAdjust.py E [  8%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_NwarpApply.py E [  9%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_NwarpCat.py E [  9%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_OneDToolPy.py E [  9%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_OutlierCount.py E [  9%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_QualityIndex.py E [  9%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Qwarp.py E [  9%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_QwarpPlusMinus.py E [  9%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_ROIStats.py E [  9%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_ReHo.py E [  9%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Refit.py E [  9%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Remlfit.py E [  9%]
# E                                                                        [  9%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Resample.py E [ 10%]
# E                                                                        [ 10%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Retroicor.py E [ 10%]
# E                                                                        [ 10%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_SVMTest.py E [ 10%]
# E                                                                        [ 10%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_SVMTrain.py E [ 10%]
# E                                                                        [ 10%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Seg.py E [ 10%]
# E                                                                        [ 10%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_SkullStrip.py E [ 10%]
# E                                                                        [ 10%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Synthesize.py E [ 10%]
# E                                                                        [ 10%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_TCat.py E [ 10%]
# E                                                                        [ 10%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_TCatSubBrick.py E [ 10%]
# E                                                                        [ 10%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_TCorr1D.py E [ 10%]
# E                                                                        [ 10%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_TCorrMap.py E [ 10%]
# E                                                                        [ 10%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_TCorrelate.py E [ 10%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_TNorm.py E [ 11%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_TProject.py E [ 11%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_TShift.py E [ 11%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_TSmooth.py E [ 11%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_TStat.py E [ 11%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_To3D.py E [ 11%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Undump.py E [ 11%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Unifize.py E [ 11%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Volreg.py E [ 11%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Warp.py E [ 11%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_ZCutUp.py E [ 11%]
# E                                                                        [ 11%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Zcat.py E [ 12%]
# E                                                                        [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_auto_Zeropad.py E [ 12%]
# E                                                                        [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/afni/tests/test_extra_Deconvolve.py E [ 12%]
#                                                                          [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_AI.py E [ 12%]
# E                                                                        [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_ANTS.py E [ 12%]
# E                                                                        [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_ANTSCommand.py E [ 12%]
#                                                                          [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_AffineInitializer.py E [ 12%]
# E                                                                        [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_ApplyTransforms.py E [ 12%]
# E                                                                        [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_ApplyTransformsToPoints.py E [ 12%]
# E                                                                        [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_Atropos.py E [ 12%]
# E                                                                        [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_AverageAffineTransform.py E [ 12%]
# E                                                                        [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_AverageImages.py E [ 12%]
# E                                                                        [ 12%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_BrainExtraction.py E [ 12%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_ComposeMultiTransform.py E [ 13%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_CompositeTransformUtil.py E [ 13%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_ConvertScalarImageToRGB.py E [ 13%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_CorticalThickness.py E [ 13%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_CreateJacobianDeterminantImage.py E [ 13%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_CreateTiledMosaic.py E [ 13%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_DenoiseImage.py E [ 13%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_GenWarpFields.py E [ 13%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_ImageMath.py E [ 13%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_JointFusion.py E [ 13%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_KellyKapowski.py E [ 13%]
# E                                                                        [ 13%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_LabelGeometry.py E [ 14%]
# E                                                                        [ 14%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_LaplacianThickness.py E [ 14%]
# E                                                                        [ 14%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_MeasureImageSimilarity.py E [ 14%]
# E                                                                        [ 14%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_MultiplyImages.py E [ 14%]
# E                                                                        [ 14%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_N4BiasFieldCorrection.py E [ 14%]
# E                                                                        [ 14%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_Registration.py E [ 14%]
# E                                                                        [ 14%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_RegistrationSynQuick.py E [ 14%]
# E                                                                        [ 14%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_ResampleImageBySpacing.py E [ 14%]
# E                                                                        [ 14%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_ThresholdImage.py E [ 14%]
# E                                                                        [ 14%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_WarpImageMultiTransform.py E [ 14%]
# E                                                                        [ 14%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_WarpTimeSeriesImageMultiTransform.py E [ 14%]
# E                                                                        [ 14%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_antsIntroduction.py E [ 14%]
# E                                                                        [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_auto_buildtemplateparallel.py E [ 15%]
# E                                                                        [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_extra_Registration.py E [ 15%]
#                                                                          [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_resampling.py E [ 15%]
# EEEEEE                                                                   [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/ants/tests/test_segmentation.py E [ 15%]
# E                                                                        [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_auto_BaseInterface.py E [ 15%]
#                                                                          [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_auto_CommandLine.py E [ 15%]
#                                                                          [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_auto_LibraryBaseInterface.py E [ 15%]
#                                                                          [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_auto_MpiCommandLine.py E [ 15%]
#                                                                          [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_auto_SEMLikeCommandLine.py E [ 15%]
#                                                                          [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_auto_SimpleInterface.py E [ 15%]
#                                                                          [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_auto_StdOutCommandLine.py E [ 15%]
#                                                                          [ 15%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_core.py E [ 15%]
# EEEEEEEEEEEEEEE                                                          [ 16%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_resource_monitor.py s [ 16%]
# sssssss                                                                  [ 16%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_specs.py E [ 16%]
# EsEEEEEEEEEEEE                                                           [ 17%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_support.py E [ 17%]
# EEEEE                                                                    [ 17%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/tests/test_traits_extension.py E [ 17%]
#                                                                          [ 17%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_BDP.py E [ 17%]
#                                                                          [ 17%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Bfc.py E [ 17%]
# E                                                                        [ 17%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Bse.py E [ 18%]
# E                                                                        [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Cerebro.py E [ 18%]
# E                                                                        [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Cortex.py E [ 18%]
# E                                                                        [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Dewisp.py E [ 18%]
# E                                                                        [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Dfs.py E [ 18%]
# E                                                                        [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Hemisplit.py E [ 18%]
# E                                                                        [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Pialmesh.py E [ 18%]
# E                                                                        [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Pvc.py E [ 18%]
# E                                                                        [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_SVReg.py E [ 18%]
#                                                                          [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Scrubmask.py E [ 18%]
# E                                                                        [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Skullfinder.py E [ 18%]
# E                                                                        [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_Tca.py E [ 18%]
# E                                                                        [ 18%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/brainsuite/tests/test_auto_ThicknessPVC.py E [ 19%]
#                                                                          [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_AnalyzeHeader.py E [ 19%]
# E                                                                        [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_ComputeEigensystem.py E [ 19%]
# E                                                                        [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_ComputeFractionalAnisotropy.py E [ 19%]
# E                                                                        [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_ComputeMeanDiffusivity.py E [ 19%]
# E                                                                        [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_ComputeTensorTrace.py E [ 19%]
# E                                                                        [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_Conmat.py E [ 19%]
# E                                                                        [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_DT2NIfTI.py E [ 19%]
# E                                                                        [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_DTIFit.py E [ 19%]
# E                                                                        [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_DTLUTGen.py E [ 19%]
# E                                                                        [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_DTMetric.py E [ 19%]
# E                                                                        [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_FSL2Scheme.py E [ 19%]
# E                                                                        [ 19%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_Image2Voxel.py E [ 20%]
# E                                                                        [ 20%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_ImageStats.py E [ 20%]
# E                                                                        [ 20%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_LinRecon.py E [ 20%]
# E                                                                        [ 20%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_MESD.py E [ 20%]
# E                                                                        [ 20%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_ModelFit.py E [ 20%]
# E                                                                        [ 20%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_NIfTIDT2Camino.py E [ 20%]
# E                                                                        [ 20%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_PicoPDFs.py E [ 20%]
# E                                                                        [ 20%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_ProcStreamlines.py E [ 20%]
# E                                                                        [ 20%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_QBallMX.py E [ 20%]
# E                                                                        [ 20%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_SFLUTGen.py E [ 20%]
# E                                                                        [ 20%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_SFPICOCalibData.py E [ 20%]
# E                                                                        [ 20%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_SFPeaks.py E [ 20%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_Shredder.py E [ 21%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_Track.py E [ 21%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_TrackBallStick.py E [ 21%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_TrackBayesDirac.py E [ 21%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_TrackBedpostxDeter.py E [ 21%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_TrackBedpostxProba.py E [ 21%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_TrackBootstrap.py E [ 21%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_TrackDT.py E [ 21%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_TrackPICo.py E [ 21%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_TractShredder.py E [ 21%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino/tests/test_auto_VtkStreamlines.py E [ 21%]
# E                                                                        [ 21%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino2trackvis/tests/test_auto_Camino2Trackvis.py E [ 22%]
# E                                                                        [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/camino2trackvis/tests/test_auto_Trackvis2Camino.py E [ 22%]
# E                                                                        [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/cmtk/tests/test_auto_AverageNetworks.py E [ 22%]
# E                                                                        [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/cmtk/tests/test_auto_CFFBaseInterface.py E [ 22%]
#                                                                          [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/cmtk/tests/test_auto_CFFConverter.py E [ 22%]
# E                                                                        [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/cmtk/tests/test_auto_CreateMatrix.py E [ 22%]
# E                                                                        [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/cmtk/tests/test_auto_CreateNodes.py E [ 22%]
# E                                                                        [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/cmtk/tests/test_auto_MergeCNetworks.py E [ 22%]
# E                                                                        [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/cmtk/tests/test_auto_NetworkBasedStatistic.py E [ 22%]
# E                                                                        [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/cmtk/tests/test_auto_NetworkXMetrics.py E [ 22%]
# E                                                                        [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/cmtk/tests/test_auto_Parcellate.py E [ 22%]
# E                                                                        [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/cmtk/tests/test_auto_ROIGen.py E [ 22%]
# E                                                                        [ 22%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/cmtk/tests/test_nbs.py E [ 23%]
# s                                                                        [ 23%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/diffusion_toolkit/tests/test_auto_DTIRecon.py E [ 23%]
# E                                                                        [ 23%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/diffusion_toolkit/tests/test_auto_DTITracker.py E [ 23%]
# E                                                                        [ 23%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/diffusion_toolkit/tests/test_auto_HARDIMat.py E [ 23%]
# E                                                                        [ 23%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/diffusion_toolkit/tests/test_auto_ODFRecon.py E [ 23%]
# E                                                                        [ 23%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/diffusion_toolkit/tests/test_auto_ODFTracker.py E [ 23%]
# E                                                                        [ 23%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/diffusion_toolkit/tests/test_auto_SplineFilter.py E [ 23%]
# E                                                                        [ 23%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/diffusion_toolkit/tests/test_auto_TrackMerge.py E [ 23%]
# E                                                                        [ 23%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/dipy/tests/test_auto_APMQball.py E [ 23%]
# E                                                                        [ 23%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/dipy/tests/test_auto_CSD.py E [ 23%]
# E                                                                        [ 23%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/dipy/tests/test_auto_DTI.py E [ 23%]
# E                                                                        [ 23%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/dipy/tests/test_auto_Denoise.py E [ 23%]
# E                                                                        [ 24%]
# ../anaconda3/lib/python3.6/site-packages/nipype/interfaces/dipy/tests/test_auto_DipyBaseInterface.py E [ 24%]
#                                                                          [ 24%]
# ...
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ______________________ ERROR at setup of test_cwd_cached _______________________
#
# request = <SubRequest '_docdir' for <Function test_cwd_cached>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ______________________ ERROR at setup of test_debug_mode _______________________
#
# request = <SubRequest '_docdir' for <Function test_debug_mode>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ______________________ ERROR at setup of test_rev_opt_map ______________________
#
# request = <SubRequest '_docdir' for <Function test_rev_opt_map>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# _______________________ ERROR at setup of test_build_doc _______________________
#
# request = <SubRequest '_docdir' for <Function test_build_doc>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ______________________ ERROR at setup of test_insert_doc _______________________
#
# request = <SubRequest '_docdir' for <Function test_insert_doc>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ____________ ERROR at setup of test_split_filename[foo.nii-split0] _____________
#
# request = <SubRequest '_docdir' for <Function test_split_filename[foo.nii-split0]>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ___________ ERROR at setup of test_split_filename[foo.nii.gz-split1] ___________
#
# request = <SubRequest '_docdir' for <Function test_split_filename[foo.nii.gz-split1]>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# _________ ERROR at setup of test_split_filename[foo.niml.dset-split2] __________
#
# request = <SubRequest '_docdir' for <Function test_split_filename[foo.niml.dset-split2]>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# _____ ERROR at setup of test_split_filename[/usr/local/foo.nii.gz-split3] ______
#
# request = <SubRequest '_docdir' for <Function test_split_filename[/usr/local/foo.nii.gz-split3]>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ______ ERROR at setup of test_split_filename[../usr/local/foo.nii-split4] ______
#
# request = <SubRequest '_docdir' for <Function test_split_filename[../usr/local/foo.nii-split4]>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# _____ ERROR at setup of test_split_filename[/usr/local/foo.a.b.c.d-split5] _____
#
# request = <SubRequest '_docdir' for <Function test_split_filename[/usr/local/foo.a.b.c.d-split5]>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# __________ ERROR at setup of test_split_filename[/usr/local/-split6] ___________
#
# request = <SubRequest '_docdir' for <Function test_split_filename[/usr/local/-split6]>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ____________________ ERROR at setup of test_fname_presuffix ____________________
#
# request = <SubRequest '_docdir' for <Function test_fname_presuffix>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ___________________ ERROR at setup of test_fnames_presuffix ____________________
#
# request = <SubRequest '_docdir' for <Function test_fnames_presuffix>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ______ ERROR at setup of test_hash_rename[foobar.nii-foobar_0xabc123.nii] ______
#
# request = <SubRequest '_docdir' for <Function test_hash_rename[foobar.nii-foobar_0xabc123.nii]>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ___ ERROR at setup of test_hash_rename[foobar.nii.gz-foobar_0xabc123.nii.gz] ___
#
# request = <SubRequest '_docdir' for <Function test_hash_rename[foobar.nii.gz-foobar_0xabc123.nii.gz]>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# _____________________ ERROR at setup of test_check_forhash _____________________
#
# request = <SubRequest '_docdir' for <Function test_check_forhash>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# _______________________ ERROR at setup of test_copyfile ________________________
#
# request = <SubRequest '_docdir' for <Function test_copyfile>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# _____________________ ERROR at setup of test_copyfile_true _____________________
#
# request = <SubRequest '_docdir' for <Function test_copyfile_true>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# _______________________ ERROR at setup of test_copyfiles _______________________
#
# request = <SubRequest '_docdir' for <Function test_copyfiles>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# _______________________ ERROR at setup of test_linkchain _______________________
#
# request = <SubRequest '_docdir' for <Function test_linkchain>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ________________________ ERROR at setup of test_recopy _________________________
#
# request = <SubRequest '_docdir' for <Function test_recopy>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# _____________________ ERROR at setup of test_copyfallback ______________________
#
# request = <SubRequest '_docdir' for <Function test_copyfallback>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ___________________ ERROR at setup of test_get_related_files ___________________
#
# request = <SubRequest '_docdir' for <Function test_get_related_files>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ____________ ERROR at setup of test_get_related_files_noninclusive _____________
#
# request = <SubRequest '_docdir' for <Function test_get_related_files_noninclusive>>
#
#     @pytest.fixture(autouse=True)
#     def _docdir(request):
#         """Grabbed from https://stackoverflow.com/a/46991331"""
#         # Trigger ONLY for the doctests.
#         doctest_plugin = request.config.pluginmanager.getplugin("doctest")
# >       if isinstance(request.node, doctest_plugin.DoctestItem):
# E       AttributeError: 'NoneType' object has no attribute 'DoctestItem'
#
# /home/jordan/anaconda3/lib/python3.6/site-packages/nipype/conftest.py:28: AttributeError
# ____________ ERROR at setup of test_ensure_list[foo.nii-expected0] _____________

# %%
nipype.get_info()
# Out:
# {'pkg_path': '/home/jordan/anaconda3/lib/python3.6/site-packages/nipype',
#  'commit_source': 'installation',
#  'commit_hash': '72945ef34',
#  'nipype_version': '1.5.0',
#  'sys_version': '3.6.8 |Anaconda, Inc.| (default, Dec 30 2018, 01:22:34) \n[GCC 7.3.0]',
#  'sys_executable': '/home/jordan/anaconda3/bin/python',
#  'sys_platform': 'linux',
#  'numpy_version': '1.16.2',
#  'scipy_version': '1.2.1',
#  'networkx_version': '2.2',
#  'nibabel_version': '2.5.0',
#  'traits_version': '5.1.1'}
